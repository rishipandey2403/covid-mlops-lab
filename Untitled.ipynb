# %%
# %%writefile src/serving/app.py
from fastapi import FastAPI
from pydantic import BaseModel
import joblib
import numpy as np

# Load model ONCE when app starts
MODEL_PATH = "artifacts/models/strong_xgboost.joblib"
model = joblib.load(MODEL_PATH)

app = FastAPI(title="COVID Mortality Prediction API")

class Patient(BaseModel):
    features: list

@app.post("/predict")
def predict(patient: Patient):
    X = np.array(patient.features).reshape(1, -1)
    prediction = model.predict(X)[0]
    return {
        "prediction": int(prediction),
        "meaning": "Death" if prediction == 1 else "Survived"
    }
# Out:
# Overwriting src/serving/app.py

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in e:\anaconda\application\lib\site-packages (0.111.1)
# Requirement already satisfied: uvicorn in e:\anaconda\application\lib\site-packages (0.30.3)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in e:\anaconda\application\lib\site-packages (from fastapi) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in e:\anaconda\application\lib\site-packages (from fastapi) (1.10.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in e:\anaconda\application\lib\site-packages (from fastapi) (4.9.0)
# Requirement already satisfied: fastapi-cli>=0.0.2 in e:\anaconda\application\lib\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in e:\anaconda\application\lib\site-packages (from fastapi) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in e:\anaconda\application\lib\site-packages (from fastapi) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in e:\anaconda\application\lib\site-packages (from fastapi) (0.0.9)
# Requirement already satisfied: email_validator>=2.0.0 in e:\anaconda\application\lib\site-packages (from fastapi) (2.2.0)
# Requirement already satisfied: click>=7.0 in e:\anaconda\application\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in e:\anaconda\application\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in e:\anaconda\application\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in e:\anaconda\application\lib\site-packages (from email_validator>=2.0.0->fastapi) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in e:\anaconda\application\lib\site-packages (from email_validator>=2.0.0->fastapi) (3.4)
# Requirement already satisfied: typer>=0.12.3 in e:\anaconda\application\lib\site-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in e:\anaconda\application\lib\site-packages (from httpx>=0.23.0->fastapi) (4.2.0)
# Requirement already satisfied: certifi in e:\anaconda\application\lib\site-packages (from httpx>=0.23.0->fastapi) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in e:\anaconda\application\lib\site-packages (from httpx>=0.23.0->fastapi) (1.0.5)
# Requirement already satisfied: sniffio in e:\anaconda\application\lib\site-packages (from httpx>=0.23.0->fastapi) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\application\lib\site-packages (from jinja2>=2.11.2->fastapi) (2.1.3)
# Requirement already satisfied: httptools>=0.5.0 in e:\anaconda\application\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in e:\anaconda\application\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.21.0)
# Requirement already satisfied: pyyaml>=5.1 in e:\anaconda\application\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Requirement already satisfied: watchfiles>=0.13 in e:\anaconda\application\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in e:\anaconda\application\lib\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (12.0)
# Requirement already satisfied: shellingham>=1.3.0 in e:\anaconda\application\lib\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in e:\anaconda\application\lib\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.3.5)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in e:\anaconda\application\lib\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\anaconda\application\lib\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in e:\anaconda\application\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%writefile requirements.txt
# numpy
# pandas
# scikit-learn
# joblib
# xgboost
# mlflow
# fastapi
# uvicorn
# Out:
# Overwriting requirements.txt

# %%
# %%writefile .github/workflows/train.yml
# name: Train COVID Model
#
# on:
#   push:
#     branches: [ main ]
#   pull_request:
#
# jobs:
#   train:
#     runs-on: ubuntu-latest
#
#     steps:
#     - name: Checkout code
#       uses: actions/checkout@v3
#
#     - name: Setup Python
#       uses: actions/setup-python@v4
#       with:
#         python-version: '3.10'
#
#     - name: Install dependencies
#       run: |
#         pip install --upgrade pip
#         pip install -r requirements.txt
#
#     - name: Run training pipeline
#       run: |
#         python src/train.py
# Out:
# Writing .github/workflows/train.yml
